# %%
#pip install openpyxl

# %%
import pandas as pd

xl = pd.DataFrame(pd.read_excel( 'data/combined_pose_data.xlsx'))
# Convert and save to CSV
xl.to_csv('data/combined_pose_data.csv', index=False)

# %%
df = pd.read_csv('data/combined_pose_data.csv')
df.head()
# Out:
#   class_name         metadata                 x1                 y1  \
# 0     ayesha  spin, true_grip  0.550901532173157  0.452469408512116
# 1     ayesha  spin, true_grip  0.550313651561737  0.456584453582764
# 2     ayesha  spin, true_grip  0.550200760364533  0.460396617650986
# 3     ayesha  spin, true_grip  0.554080247879028  0.459564983844757
# 4     ayesha  spin, true_grip   0.55398041009903  0.459447383880615
#
#                    z1                 v1                 x2  \
# 0  -0.371652334928513  0.999634027481079  0.551996767520905
# 1  -0.408107221126556  0.999585211277008  0.551725804805756
# 2  -0.407223522663116  0.999601304531097  0.551819682121277
# 3  -0.400975495576859  0.999601781368256  0.554280340671539
# 4  -0.382720917463303  0.999635696411133  0.555034399032593
#
#                   y2                  z2                 v2  ...  \
# 0  0.459261238574982  -0.373692780733109  0.999179065227509  ...
# ...

# %%
delete_cols = ['x34', 'y34', 'z34', 'v34']
df = df.drop(columns=delete_cols, errors='ignore')
df.to_csv('data/combined_pose_data.csv', index=False)
